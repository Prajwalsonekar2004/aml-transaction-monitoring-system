# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\sudhanshu\Downloads\AML DATAset\HI-Medium_Trans.csv",
                            nrows=5_000_000)

df.shape
# Out:
# (5000000, 11)

# %%
df.head()
# Out:
#           Timestamp  From Bank    Account  To Bank  Account.1  \
# 0  2022/09/01 00:17         20  800104D70       20  800104D70
# 1  2022/09/01 00:02       3196  800107150     3196  800107150
# 2  2022/09/01 00:17       1208  80010E430     1208  80010E430
# 3  2022/09/01 00:03       1208  80010E650       20  80010E6F0
# 4  2022/09/01 00:02       1208  80010E650       20  80010EA30
#
#    Amount Received Receiving Currency  Amount Paid Payment Currency  \
# 0          6794.63          US Dollar      6794.63        US Dollar
# 1          7739.29          US Dollar      7739.29        US Dollar
# 2          1880.23          US Dollar      1880.23        US Dollar
# 3      73966883.00          US Dollar  73966883.00        US Dollar
# 4      45868454.00          US Dollar  45868454.00        US Dollar
#
#   Payment Format  Is Laundering
# 0   Reinvestment              0
# 1   Reinvestment              0
# 2   Reinvestment              0
# 3         Cheque              0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000000 entries, 0 to 4999999
# Data columns (total 11 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Timestamp           object
#  1   From Bank           int64
#  2   Account             object
#  3   To Bank             int64
#  4   Account.1           object
#  5   Amount Received     float64
#  6   Receiving Currency  object
#  7   Amount Paid         float64
#  8   Payment Currency    object
#  9   Payment Format      object
#  10  Is Laundering       int64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 419.6+ MB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000000 entries, 0 to 4999999
# Data columns (total 11 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Timestamp           datetime64[ns]
#  1   From Bank           int64
#  2   Account             object
#  3   To Bank             int64
#  4   Account.1           object
#  5   Amount Received     float64
#  6   Receiving Currency  object
#  7   Amount Paid         float64
#  8   Payment Currency    object
#  9   Payment Format      object
#  10  Is Laundering       int64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(5)
# memory usage: 419.6+ MB

# %%
df.isnull().sum()
# Out:
# Timestamp             0
# From Bank             0
# Account               0
# To Bank               0
# Account.1             0
# Amount Received       0
# Receiving Currency    0
# Amount Paid           0
# Payment Currency      0
# Payment Format        0
# Is Laundering         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Timestamp', 'From Bank', 'Account', 'To Bank', 'Account.1',
#        'Amount Received', 'Receiving Currency', 'Amount Paid',
#        'Payment Currency', 'Payment Format', 'Is Laundering'],
#       dtype='object')

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(" ", "_")

# %%
df.columns
# Out:
# Index(['timestamp', 'from_bank', 'account', 'to_bank', 'account.1',
#        'amount_received', 'receiving_currency', 'amount_paid',
#        'payment_currency', 'payment_format', 'is_laundering'],
#       dtype='object')

# %%
# from sqlalchemy import create_engine

# engine = create_engine(f"postgresql+psycopg2://postgres:25012004@localhost:5433/AML_Project")

# df.head(0).to_sql('aml_transactions', engine, if_exists='replace', index=False)

# %%
# df.to_csv('aml_transactions_clean.csv', index=False)

# %%
# import psycopg2

# conn = psycopg2.connect(
#     host = "localhost",
#     port = "5433",
#     database = "AML_Project",
#     user = "postgres",
#     password = "25012004"
# )

# cursor = conn.cursor()

# with open(r"C:\Users\sudhanshu\Downloads\Prajwal Sonekar\aml_transactions_clean.csv","r") as f:
#     cursor.copy_expert("COPY aml_transactions FROM STDIN WITH CSV HEADER",f)

# conn.commit()
# cursor.close()
# conn.close()
